# %%
import pandas as pd
import numpy as np

# %%
import mysql.connector

# %% [markdown]
# #### 데이터프레임 고급 인덱싱
# 판다스 데이터프레임의 인덱싱은 라벨, 라벨 리스트, 행 인덱스 슬라이스의 인덱싱 형태 뿐만 아니라 numpy와 같은 `,`를 이용한 `(행 인덱스, 열 인덱스)` 형식의 2차원 인덱스도 제공함
#
# - `loc` 속성 : 라벨 기반의 2차원 인덱서
# - `iloc` 속성 : 순서를 나타내는 정수 기반의 2차원 인덱서

# %% [markdown]
# #### `loc` 인덱서
# 행 인덱스 값과 열 인덱스 값을 이용하여 인덱싱을 해주는 인덱서
#
# df.loc[행인덱스값]
# df.loc[행인덱스값, 열인덱스값]

# %%
df = pd.DataFrame(np.arange(10, 22).reshape(3, 4), index=['a', 'b', 'c'], columns=['A', 'B', 'C', 'D'])
df
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21

# %%
df.loc['a']
# Out:
# A    10
# B    11
# C    12
# D    13
# Name: a, dtype: int32

# %%
df.loc[['a', 'b']]
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17

# %%
df.loc['a': 'b']
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17

# %%
df.loc[['a']]
# Out:
#     A   B   C   D
# a  10  11  12  13

# %%
df.loc[df.A > 13]  # 행A의 열이 13이 넘는 열의 행만 나타냄
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %% [markdown]
# 인덱스 값으로 열 인덱스 값을 반환하는 함수를 사용할 수 있음

# %%
def select_rows(df):
    return df.A > 12

# %%
df.loc[select_rows(df)]
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %% [markdown]
# `loc` 없이 인덱싱을 할때는 `[]`에 열 인덱스에 대한 인덱싱을 하였는데 `loc`는 열 인덱싱으로 지정할 수 없음

# %%
df.loc['A'] # 실행안됨

# %% [markdown]
# `loc` 인덱싱에서 정수로 되어있는 행이라고 할 지라도 슬라이싱시에 종료 인덱스 값에 대한 결과도 포함하여 출력됨

# %%
df2 = pd.DataFrame(np.arange(10, 26).reshape(4, 4), columns=['A', 'B', 'C', 'D'])
df2
# Out:
#     A   B   C   D
# 0  10  11  12  13
# 1  14  15  16  17
# 2  18  19  20  21
# 3  22  23  24  25

# %%
df2.loc[0:2]
# Out:
#     A   B   C   D
# 0  10  11  12  13
# 1  14  15  16  17
# 2  18  19  20  21

# %% [markdown]
# 인덱싱 값으로 행과 열 모두 지정
# `loc[행인덱스, 열인덱스]` 로 행과 열에 대한 인덱싱을 할 수 있음

# %%
df.loc['a', 'A']
# Out:
# 10

# %%
df.loc['b': ,:'C']
# Out:
#     A   B   C
# b  14  15  16
# c  18  19  20

# %%
df
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21

# %%
df.loc[df.A > 13, ['B', 'C']]
# Out:
#     B   C
# b  15  16
# c  19  20

# %% [markdown]
# #### iloc 인덱서
# `iloc` 인덱서는 `loc` 인덱서와 사용방법은 동일하나 인덱스로 지정하는 값이 순서를 나타내는 정수 값임

# %%
df
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21

# %%
df.iloc[0,1]
# Out:
# 11

# %%
df.iloc[:2,1:]
# Out:
#     B   C   D
# a  11  12  13
# b  15  16  17

# %%
df.iloc[2]
# Out:
# A    18
# B    19
# C    20
# D    21
# Name: c, dtype: int32

# %% [markdown]
# #### 파이썬으로 다음 연산을 수행한다.
#
# 1.real_estate 데이터베이스의 officetel_estate 테이블을 데이터프레임으로 가져옴
# 2.상위 10개에 대한 레코드를 가지는 데이터프레임을 생성
# 3. locale이 seoul-downtown 인 레코드를 가지는 데이터프레임을 생성
# 4.between_lease_and_lease_deposit_ratio가 10 이상인 레코드의 locale, base_month 컬럼만 가지는 데이터프레임을 생성

# %%
import mysql.connector

# %%
practice_df = None

try:
    conn = mysql.connector.connect(
        host='127.0.0.1',
        user='root',
        password='root',
        database='real_estate'
    )
    
    if conn.is_connected():
        SQL = 'SELECT * FROM officetel_estate'
        practice_df = pd.read_sql_query(SQL,conn,index_col='sequence')

except Exception as e:
    pass
finally:
    if conn.is_connected():
        conn.close()
# Out:
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_10720\3581166549.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   practice_df = pd.read_sql_query(SQL,conn,index_col='sequence')

# %%
practice_df
# Out:
#                   locale base_month  between_lease_and_lease_deposit_ratio  \
# sequence
# 1             nationwide     20-Jul                                   7.95
# 2           metropolitan     20-Jul                                   7.46
# 3               province     20-Jul                                   9.96
# 4                  seoul     20-Jul                                   7.10
# 5         seoul-downtown     20-Jul                                   6.13
# ...                  ...        ...                                    ...
# 727              gwangju     24-Jan                                   7.86
# 728              daejeon     24-Jan                                  11.42
# 729                ulsan     24-Jan                                   7.62
# 730               sejong     24-Jan                                   6.05
# 731             gyeonggi     24-Jan                                   7.09
#
#           lease_to_sale_ratio  monthly_rent_rate_of_return  \
# sequence
# 1                       83.54                         4.75
# 2                       84.31                         4.61
# 3                       80.33                         5.35
# 4                       82.80                         4.33
# 5                       79.55                         4.18
# ...                       ...                          ...
# 727                     83.49                         6.10
# 728                     86.32                         7.54
# 729                     83.34                         5.32
# 730                     86.15                         6.30
# 731                     85.40                         5.35
#
#           average_lease_on_deposit_price  \
# sequence
# 1                                 163525
# 2                                 175996
# 3                                 111980
# 4                                 199524
# 5                                 235665
# ...                                  ...
# 727                               105940
# 728                               101796
# 729                               117651
# 730                                97749
# 731                               183448
#
#           average_lease_on_deposit_price_per_unit  \
# sequence
# 1                                            4370
# 2                                            4797
# 3                                            2603
# 4                                            6033
# 5                                            6405
# ...                                           ...
# 727                                          2595
# 728                                          2355
# 729                                          2921
# 730                                          3522
# 731                                          4649
#
#           midian_lease_on_deposit_price  \
# sequence
# 1                                156386
# 2                                167524
# 3                                110353
# 4                                190788
# 5                                223768
# ...                                 ...
# 727                              110677
# 728                              101257
# 729                              116039
# 730                               93146
# 731                              169240
#
#           midian_lease_on_deposit_price_per_unit  average_monthly_rent_price  \
# sequence
# 1                                           4266                       13107
# 2                                           4682                       13656
# 3                                           2545                       10837
# 4                                           6025                       15250
# 5                                           6221                       13906
# ...                                          ...                         ...
# 727                                         2551                        9126
# 728                                         2201                       12090
# 729                                         2899                        9253
# 730                                         3403                        6064
# 731                                         4485                       15009
#
#           average_monthly_rent_price_unit  midian_average_monthly_rent_price  \
# sequence
# 1                                     661                              10705
# 2                                     698                              11247
# 3                                     507                               8466
# 4                                     777                              12876
# 5                                     946                              13701
# ...                                   ...                                ...
# 727                                   545                               8927
# 728                                   556                               9341
# 729                                   563                               9621
# 730                                   552                               5898
# 731                                   806                              10620
#
#           midian_average_monthly_rent_price_unit  average_sale_price  \
# sequence
# 1                                            634              203454
# 2                                            668              217040
# 3                                            492              147304
# 4                                            744              251315
# 5                                            919              310153
# ...                                          ...                 ...
# 727                                          540              132817
# 728                                          550              123572
# 729                                          555              144356
# 730                                          547              118063
# 731                                          767              231384
#
#           average_price_per_unit  midian_average_sale_price  \
# sequence
# 1                           5272                     190155
# 2                           5751                     202398
# 3                           3295                     139555
# 4                           7342                     235222
# 5                           8155                     307248
# ...                          ...                        ...
# 727                         3124                     130755
# 728                         2742                     118458
# 729                         3493                     140185
# 730                         4101                     111110
# 731                         5558                     214777
#
#           midian_average_price_per_unit
# sequence
# 1                                  4997
# 2                                  5434
# 3                                  3191
# 4                                  7064
# 5                                  7901
# ...                                 ...
# 727                                2901
# 728                                2513
# 729                                3457
# 730                                3869
# 731                                5332
#
# [731 rows x 17 columns]

# %%
# 상위 10개에 대한 레코드를 가지는 데이터프레임을 생성
practice_df.iloc[:10]
# Out:
#                       locale base_month  \
# sequence
# 1                 nationwide     20-Jul
# 2               metropolitan     20-Jul
# 3                   province     20-Jul
# 4                      seoul     20-Jul
# 5             seoul-downtown     20-Jul
# 6         seoul-northeastern     20-Jul
# 7         seoul-northwestern     20-Jul
# 8         seoul-southwestern     20-Jul
# 9         seoul-southeastern     20-Jul
# 10                     busan     20-Jul
#
#           between_lease_and_lease_deposit_ratio  lease_to_sale_ratio  \
# sequence
# 1                                          7.95                83.54
# 2                                          7.46                84.31
# 3                                          9.96                80.33
# 4                                          7.10                82.80
# 5                                          6.13                79.55
# 6                                          8.00                82.64
# 7                                          6.73                83.75
# 8                                          8.01                85.62
# 9                                          5.89                79.71
# 10                                        10.88                79.26
#
#           monthly_rent_rate_of_return  average_lease_on_deposit_price  \
# sequence
# 1                                4.75                          163525
# 2                                4.61                          175996
# 3                                5.35                          111980
# 4                                4.33                          199524
# 5                                4.18                          235665
# 6                                4.95                          136655
# 7                                4.46                          187934
# 8                                4.33                          189461
# 9                                3.99                          238402
# 10                               5.23                          119095
#
#           average_lease_on_deposit_price_per_unit  \
# sequence
# 1                                            4370
# 2                                            4797
# 3                                            2603
# 4                                            6033
# 5                                            6405
# 6                                            4778
# 7                                            6434
# 8                                            5827
# 9                                            6637
# 10                                           2713
#
#           midian_lease_on_deposit_price  \
# sequence
# 1                                156386
# 2                                167524
# 3                                110353
# 4                                190788
# 5                                223768
# 6                                135819
# 7                                180747
# 8                                182424
# 9                                223680
# 10                               117286
#
#           midian_lease_on_deposit_price_per_unit  average_monthly_rent_price  \
# sequence
# 1                                           4266                       13107
# 2                                           4682                       13656
# 3                                           2545                       10837
# 4                                           6025                       15250
# 5                                           6221                       13906
# 6                                           4462                       11135
# 7                                           6370                       11923
# 8                                           6015                       18688
# 9                                           6606                       14693
# 10                                          2634                       12155
#
#           average_monthly_rent_price_unit  midian_average_monthly_rent_price  \
# sequence
# 1                                     661                              10705
# 2                                     698                              11247
# 3                                     507                               8466
# 4                                     777                              12876
# 5                                     946                              13701
# 6                                     612                              11519
# 7                                     768                              11474
# 8                                     695                              13675
# 9                                     921                              12859
# 10                                    533                               9058
#
#           midian_average_monthly_rent_price_unit  average_sale_price  \
# sequence
# 1                                            634              203454
# 2                                            668              217040
# 3                                            492              147304
# 4                                            744              251315
# 5                                            919              310153
# 6                                            608              166160
# 7                                            710              233877
# 8                                            670              233015
# 9                                            869              307776
# 10                                           511              160715
#
#           average_price_per_unit  midian_average_sale_price  \
# sequence
# 1                           5272                     190155
# 2                           5751                     202398
# 3                           3295                     139555
# 4                           7342                     235222
# 5                           8155                     307248
# 6                           5751                     162059
# 7                           7629                     207423
# 8                           6841                     216063
# 9                           8424                     287112
# 10                          3494                     150766
#
#           midian_average_price_per_unit
# sequence
# 1                                  4997
# 2                                  5434
# 3                                  3191
# 4                                  7064
# 5                                  7901
# 6                                  5416
# 7                                  7353
# 8                                  6744
# 9                                  7919
# 10                                 3371

# %%
# between_lease_and_lease_deposit_ratio가 10 이상인 레코드의 locale, base_month 컬럼만 가지는 데이터프레임을 생성
practice_df.loc[practice_df. between_lease_and_lease_deposit_ratio >= 10,['between_lease_and_lease_deposit_ratio','locale','base_month']]
# Out:
#           between_lease_and_lease_deposit_ratio              locale base_month
# sequence
# 10                                        10.88               busan     20-Jul
# 27                                        10.88               busan     20-Aug
# 44                                        10.89               busan     20-Sep
# 54                                        10.06            province     20-Oct
# 61                                        11.04               busan     20-Oct
# ...                                         ...                 ...        ...
# 700                                       10.05            province     23-Dec
# 707                                       10.84               busan     23-Dec
# 711                                       10.58             daejeon     23-Dec
# 722                                       11.69  seoul-southwestern     24-Jan
# 728                                       11.42             daejeon     24-Jan
#
# [87 rows x 3 columns]
