# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
# import matplotlib.fontmanager as fm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('population.csv')
df
# Out:
#         date region   number_of_households  population_sum  population_male  \
# 0    2023-01   대연1동                   9290           15787             7993
# 1    2023-01   대연3동                  16199           33022            16168
# 2    2023-01   대연4동                   5420           11991             5848
# 3    2023-01   대연5동                   8354           16807             8050
# 4    2023-01   대연6동                   5833           14929             7161
# ..       ...     ...                   ...             ...              ...
# 199  2023-12    우암동                   5730           12281             6006
# 200  2023-12   문현1동                   4835           10993             5405
# 201  2023-12   문현2동                   4881            7916             3961
# 202  2023-12   문현3동                   7053           16395             7963
# 203  2023-12   문현4동                   4344            8880             4308
#
# ...

# %%
# 세대 수 평균
data = df.number_of_households.mean().round(2)
data
# Out:
# 6967.25

# %%
# 'region' 컬럼
df['region']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ITPS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 'region' 컬럼
# ...

# %%
# 월 별 합계(남구 전체)
df.groupby(df.date).sum()

# %%
# 세대 수 총합
df['number_of_households'].sum()
# Out:
# 1421318

# %%
df_copy = df

# %%
del df_copy['  반  ']
del df_copy['  통  ']
del df_copy['area']
del df_copy['composition_ratio']
df_copy.head()
# Out:
#       date region   number_of_households  population_sum  population_male  \
# 0  2023-01   대연1동                   9290           15787             7993
# 1  2023-01   대연3동                  16199           33022            16168
# 2  2023-01   대연4동                   5420           11991             5848
# 3  2023-01   대연5동                   8354           16807             8050
# 4  2023-01   대연6동                   5833           14929             7161
#
#    population_female  population_18over_sum  population_18over_male  \
# 0               7794                  14775                    7486
# 1              16854                  28032                   13566
# 2               6143                  10369                    5012
# 3               8757                  14908                    7052
# 4               7768                  12043                    5717
#
#    population_18over_female  population_65over_sum  population_65over_male  \
# ...

# %%
# 세대 수부터 65세 이상 여성 인구까지 합계
df_sum = df_copy.sum()
df_sum['number_of_households' : 'population_65over_female']
# Out:
# number_of_households        1421318
# population_sum              3065264
# population_male             1494728
# population_female           1570536
# population_18over_sum       2680907
# population_18over_male      1297318
# population_18over_female    1383589
# population_65over_sum        696584
# population_65over_male       301606
# population_65over_female     394978
# dtype: object

# %%
# 2023-01 데이터만 따로 보기
df_copy[df_copy.date.str.contains('2023-01')]
# Out:
#        date  region   number_of_households  population_sum  population_male  \
# 0   2023-01    대연1동                   9290           15787             7993
# 1   2023-01    대연3동                  16199           33022            16168
# 2   2023-01    대연4동                   5420           11991             5848
# 3   2023-01    대연5동                   8354           16807             8050
# 4   2023-01    대연6동                   5833           14929             7161
# 5   2023-01    용호1동                  16997           43020            20600
# 6   2023-01    용호2동                   7180           17602             8578
# 7   2023-01    용호3동                   5602           11661             5624
# 8   2023-01    용호4동                   3759            8122             3891
# 9   2023-01   용 당 동                   3469            8020             4055
# 10  2023-01    감만1동                   4887           10427             5333
# ...

# %%
df_copy[df_copy.date.str.contains('2023-01')]['number_of_households'].mean().round(2)
# Out:
# 6921.65

# %%
df_copy[df_copy.date.str.contains('2023-02')]
# Out:
#        date  region   number_of_households  population_sum  population_male  \
# 17  2023-02    대연1동                   9419           15873             8045
# 18  2023-02    대연3동                  16446           33185            16265
# 19  2023-02    대연4동                   5426           11952             5813
# 20  2023-02    대연5동                   8392           16807             8052
# 21  2023-02    대연6동                   5835           14871             7134
# 22  2023-02    용호1동                  17015           43012            20611
# 23  2023-02    용호2동                   7556           18386             8940
# 24  2023-02    용호3동                   5567           11536             5567
# 25  2023-02    용호4동                   3734            8015             3848
# 26  2023-02   용 당 동                   3462            8007             4037
# 27  2023-02    감만1동                   4791           10198             5214
# ...

# %%
df_copy[df_copy.date.str.contains('2023-02')]['number_of_households'].mean().round(2)
# Out:
# 6953.47

# %%
df_copy[df_copy.date.str.contains('2023-03')]
# Out:
#        date  region   number_of_households  population_sum  population_male  \
# 34  2023-03    대연1동                   9482           15905             8061
# 35  2023-03    대연3동                  16583           33312            16338
# 36  2023-03    대연4동                   5434           11945             5811
# 37  2023-03    대연5동                   8403           16779             8040
# 38  2023-03    대연6동                   5822           14856             7137
# 39  2023-03    용호1동                  17018           42904            20539
# 40  2023-03    용호2동                   7759           18760             9112
# 41  2023-03    용호3동                   5558           11493             5556
# 42  2023-03    용호4동                   3725            7975             3817
# 43  2023-03   용 당 동                   3459            7963             4028
# 44  2023-03    감만1동                   4684            9986             5105
# ...

# %%
df_copy[df_copy.date.str.contains('2023-03')]['number_of_households'].mean().round(2)
# Out:
# 6968.35

# %%
df_copy[df_copy.date.str.contains('2023-04')]
# Out:
#        date  region   number_of_households  population_sum  population_male  \
# 51  2023-04    대연1동                   9466           15834             8017
# 52  2023-04    대연3동                  16603           33303            16331
# 53  2023-04    대연4동                   5423           11916             5800
# 54  2023-04    대연5동                   8420           16805             8061
# 55  2023-04    대연6동                   5850           14879             7138
# 56  2023-04    용호1동                  17029           42904            20535
# 57  2023-04    용호2동                   7882           19008             9221
# 58  2023-04    용호3동                   5553           11463             5543
# 59  2023-04    용호4동                   3709            7908             3790
# 60  2023-04   용 당 동                   3471            7986             4035
# 61  2023-04    감만1동                   4598            9836             5023
# ...

# %%
df_copy[df_copy.date.str.contains('2023-04')]['number_of_households'].mean().round(2)
# Out:
# 6973.88

# %%
df_copy[df_copy.date.str.contains('2023-05')]
# Out:
#        date  region   number_of_households  population_sum  population_male  \
# 68  2023-05    대연1동                   9480           15819             8006
# 69  2023-05    대연3동                  16638           33354            16350
# 70  2023-05    대연4동                   5423           11902             5794
# 71  2023-05    대연5동                   8436           16806             8063
# 72  2023-05    대연6동                   5885           14906             7145
# 73  2023-05    용호1동                  17068           42926            20561
# 74  2023-05    용호2동                   7960           19173             9296
# 75  2023-05    용호3동                   5553           11434             5522
# 76  2023-05    용호4동                   3694            7874             3766
# 77  2023-05   용 당 동                   3488            7989             4036
# 78  2023-05    감만1동                   4549            9760             4976
# ...

# %%
df_copy[df_copy.date.str.contains('2023-05')]['number_of_households'].mean().round(2)
# Out:
# 6981.53

# %%
df_copy[df_copy.date.str.contains('2023-06')]
# Out:
#         date  region   number_of_households  population_sum  population_male  \
# 85   2023-06    대연1동                   9435           15709             7945
# 86   2023-06    대연3동                  16648           33296            16320
# 87   2023-06    대연4동                   5420           11877             5770
# 88   2023-06    대연5동                   8446           16801             8065
# 89   2023-06    대연6동                   5900           14917             7151
# 90   2023-06    용호1동                  17095           42980            20580
# 91   2023-06    용호2동                   8042           19333             9359
# 92   2023-06    용호3동                   5583           11476             5549
# 93   2023-06    용호4동                   3686            7854             3754
# 94   2023-06   용 당 동                   3484            7960             4017
# 95   2023-06    감만1동                   4493            9637             4921
# ...

# %%
df_copy[df_copy.date.str.contains('2023-06')]['number_of_households'].mean().round(2)
# Out:
# 6980.76

# %%
df_copy[df_copy.date.str.contains('2023-07')]
# Out:
#         date  region   number_of_households  population_sum  population_male  \
# 102  2023-07    대연1동                   9430           15677             7948
# 103  2023-07    대연3동                  16655           33229            16286
# 104  2023-07    대연4동                   5412           11848             5751
# 105  2023-07    대연5동                   8439           16770             8027
# 106  2023-07    대연6동                   5898           14899             7142
# 107  2023-07    용호1동                  17126           42990            20587
# 108  2023-07    용호2동                   8069           19409             9398
# 109  2023-07    용호3동                   5587           11478             5555
# 110  2023-07    용호4동                   3680            7833             3738
# 111  2023-07   용 당 동                   3494            7951             4015
# 112  2023-07    감만1동                   4449            9543             4879
# ...

# %%
df_copy[df_copy.date.str.contains('2023-07')]['number_of_households'].mean().round(2)
# Out:
# 6978.88

# %%
df_copy[df_copy.date.str.contains('2023-08')]
# Out:
#         date  region   number_of_households  population_sum  population_male  \
# 119  2023-08    대연1동                   9455           15652             7943
# 120  2023-08    대연3동                  16711           33253            16295
# 121  2023-08    대연4동                   5407           11854             5746
# 122  2023-08    대연5동                   8461           16756             8032
# 123  2023-08    대연6동                   5883           14880             7142
# 124  2023-08    용호1동                  17146           43009            20587
# 125  2023-08    용호2동                   8083           19479             9437
# 126  2023-08    용호3동                   5592           11433             5517
# 127  2023-08    용호4동                   3677            7815             3732
# 128  2023-08   용 당 동                   3499            7932             4007
# 129  2023-08    감만1동                   4371            9394             4803
# ...

# %%
df_copy[df_copy.date.str.contains('2023-08')]['number_of_households'].mean().round(2)
# Out:
# 6978.88

# %%
df_copy[df_copy.date.str.contains('2023-09')]
# Out:
#         date  region   number_of_households  population_sum  population_male  \
# 136  2023-09    대연1동                   9420           15598             7915
# 137  2023-09    대연3동                  16681           33184            16259
# 138  2023-09    대연4동                   5411           11866             5744
# 139  2023-09    대연5동                   8459           16720             8012
# 140  2023-09    대연6동                   5876           14871             7134
# 141  2023-09    용호1동                  17137           42947            20555
# 142  2023-09    용호2동                   8110           19519             9454
# 143  2023-09    용호3동                   5595           11411             5505
# 144  2023-09    용호4동                   3678            7809             3723
# 145  2023-09   용 당 동                   3501            7925             4000
# 146  2023-09    감만1동                   4301            9282             4753
# ...

# %%
df_copy[df_copy.date.str.contains('2023-09')]['number_of_households'].mean().round(2)
# Out:
# 6968.82

# %%
df_copy[df_copy.date.str.contains('2023-10')]
# Out:
#         date  region   number_of_households  population_sum  population_male  \
# 153  2023-10    대연1동                   9332           15466             7858
# 154  2023-10    대연3동                  16631           33092            16209
# 155  2023-10    대연4동                   5721           12582             6099
# 156  2023-10    대연5동                   8451           16675             7983
# 157  2023-10    대연6동                   5855           14804             7104
# 158  2023-10    용호1동                  17126           42931            20535
# 159  2023-10    용호2동                   8121           19514             9452
# 160  2023-10    용호3동                   5569           11381             5492
# 161  2023-10    용호4동                   3672            7787             3711
# 162  2023-10   용 당 동                   3487            7890             3990
# 163  2023-10    감만1동                   4190            9070             4641
# ...

# %%
df_copy[df_copy.date.str.contains('2023-10')]['number_of_households'].mean().round(2)
# Out:
# 6964.12

# %%
df_copy[df_copy.date.str.contains('2023-11')]
# Out:
#         date  region   number_of_households  population_sum  population_male  \
# 170  2023-11    대연1동                   9292           15384             7798
# 171  2023-11    대연3동                  16595           33021            16177
# 172  2023-11    대연4동                   6010           13211             6409
# 173  2023-11    대연5동                   8451           16643             7963
# 174  2023-11    대연6동                   5848           14778             7097
# 175  2023-11    용호1동                  17138           42917            20539
# 176  2023-11    용호2동                   8138           19526             9450
# 177  2023-11    용호3동                   5557           11330             5458
# 178  2023-11    용호4동                   3677            7768             3714
# 179  2023-11   용 당 동                   3490            7883             3981
# 180  2023-11    감만1동                   4100            8892             4553
# ...

# %%
df_copy[df_copy.date.str.contains('2023-11')]['number_of_households'].mean().round(2)
# Out:
# 6970.29

# %%
df_copy[df_copy.date.str.contains('2023-12')]
# Out:
#         date  region   number_of_households  population_sum  population_male  \
# 187  2023-12    대연1동                   9255           15323             7751
# 188  2023-12    대연3동                  16531           32941            16141
# 189  2023-12    대연4동                   6141           13475             6530
# 190  2023-12    대연5동                   8477           16637             7948
# 191  2023-12    대연6동                   5838           14746             7082
# 192  2023-12    용호1동                  17146           42915            20524
# 193  2023-12    용호2동                   8149           19540             9461
# 194  2023-12    용호3동                   5539           11270             5425
# 195  2023-12    용호4동                   3677            7755             3711
# 196  2023-12   용 당 동                   3485            7867             3974
# 197  2023-12    감만1동                   4016            8713             4452
# ...

# %%
df_copy[df_copy.date.str.contains('2023-12')]['number_of_households'].mean().round(2)
# Out:
# 6966.29

# %%
df_copy[df_copy.date.str.contains('2023-01')]['population_sum'].mean().round(2)
# Out:
# 15070.0

# %%
df_copy[df_copy.date.str.contains('2023-02')]['population_sum'].mean().round(2)
# Out:
# 15080.65

# %%
df_copy[df_copy.date.str.contains('2023-03')]['population_sum'].mean().round(2)
# Out:
# 15078.35

# %%
df_copy[df_copy.date.str.contains('2023-04')]['population_sum'].mean().round(2)
# Out:
# 15073.94

# %%
df_copy[df_copy.date.str.contains('2023-05')]['population_sum'].mean().round(2)
# Out:
# 15066.65

# %%
df_copy[df_copy.date.str.contains('2023-06')]['population_sum'].mean().round(2)
# Out:
# 15046.24

# %%
df_copy[df_copy.date.str.contains('2023-07')]['population_sum'].mean().round(2)
# Out:
# 15023.06

# %%
df_copy[df_copy.date.str.contains('2023-08')]['population_sum'].mean().round(2)
# Out:
# 15005.59

# %%
df_copy[df_copy.date.str.contains('2023-09')]['population_sum'].mean().round(2)
# Out:
# 14976.41

# %%
df_copy[df_copy.date.str.contains('2023-10')]['population_sum'].mean().round(2)
# Out:
# 14967.94

# %%
df_copy[df_copy.date.str.contains('2023-11')]['population_sum'].mean().round(2)
# Out:
# 14968.76

# %%
df_copy[df_copy.date.str.contains('2023-12')]['population_sum'].mean().round(2)
# Out:
# 14952.06

# %%
df_copy[df_copy.date.str.contains('2023-01')]['population_18over_sum'].mean().round(2)
# Out:
# 13157.0

# %%
df_copy[df_copy.date.str.contains('2023-02')]['population_18over_sum'].mean().round(2)
# Out:
# 13173.88

# %%
df_copy[df_copy.date.str.contains('2023-03')]['population_18over_sum'].mean().round(2)
# Out:
# 13178.29

# %%
df_copy[df_copy.date.str.contains('2023-04')]['population_18over_sum'].mean().round(2)
# Out:
# 13176.94

# %%
df_copy[df_copy.date.str.contains('2023-05')]['population_18over_sum'].mean().round(2)
# Out:
# 13172.65

# %%
df_copy[df_copy.date.str.contains('2023-06')]['population_18over_sum'].mean().round(2)
# Out:
# 13157.59

# %%
df_copy[df_copy.date.str.contains('2023-07')]['population_18over_sum'].mean().round(2)
# Out:
# 13140.71

# %%
df_copy[df_copy.date.str.contains('2023-08')]['population_18over_sum'].mean().round(2)
# Out:
# 13130.29

# %%
df_copy[df_copy.date.str.contains('2023-09')]['population_18over_sum'].mean().round(2)
# Out:
# 13109.35

# %%
df_copy[df_copy.date.str.contains('2023-10')]['population_18over_sum'].mean().round(2)
# Out:
# 13102.35

# %%
df_copy[df_copy.date.str.contains('2023-11')]['population_18over_sum'].mean().round(2)
# Out:
# 13106.41

# %%
df_copy[df_copy.date.str.contains('2023-12')]['population_18over_sum'].mean().round(2)
# Out:
# 13094.94

# %%
df_copy[df_copy.date.str.contains('2023-01')]['population_65over_sum'].mean().round(2)
# Out:
# 3364.06

# %%
df_copy[df_copy.date.str.contains('2023-02')]['population_65over_sum'].mean().round(2)
# Out:
# 3373.29

# %%
df_copy[df_copy.date.str.contains('2023-03')]['population_65over_sum'].mean().round(2)
# Out:
# 3385.76

# %%
df_copy[df_copy.date.str.contains('2023-04')]['population_65over_sum'].mean().round(2)
# Out:
# 3393.76

# %%
df_copy[df_copy.date.str.contains('2023-05')]['population_65over_sum'].mean().round(2)
# Out:
# 3403.29

# %%
df_copy[df_copy.date.str.contains('2023-06')]['population_65over_sum'].mean().round(2)
# Out:
# 3408.41

# %%
df_copy[df_copy.date.str.contains('2023-07')]['population_65over_sum'].mean().round(2)
# Out:
# 3416.76

# %%
df_copy[df_copy.date.str.contains('2023-08')]['population_65over_sum'].mean().round(2)
# Out:
# 3425.53

# %%
df_copy[df_copy.date.str.contains('2023-09')]['population_65over_sum'].mean().round(2)
# Out:
# 3434.35

# %%
df_copy[df_copy.date.str.contains('2023-10')]['population_65over_sum'].mean().round(2)
# Out:
# 3446.53

# %%
df_copy[df_copy.date.str.contains('2023-11')]['population_65over_sum'].mean().round(2)
# Out:
# 3455.94

# %%
df_copy[df_copy.date.str.contains('2023-12')]['population_65over_sum'].mean().round(2)
# Out:
# 3467.82

# %%
del_df = df_copy.drop(df_copy.columns[:2], axis=1)
del_df.head()
# Out:
#    population_sum  population_male  population_female  population_18over_sum  \
# 0           15787             7993               7794                  14775
# 1           33022            16168              16854                  28032
# 2           11991             5848               6143                  10369
# 3           16807             8050               8757                  14908
# 4           14929             7161               7768                  12043
#
#    population_18over_male  population_18over_female  population_65over_sum  \
# 0                    7486                      7289                   3677
# 1                   13566                     14466                   4456
# 2                    5012                      5357                   3015
# 3                    7052                      7856                   3661
# 4                    5717                      6326                   2446
#
#    population_65over_male  population_65over_female
# ...

# %%
del_df_avg = pd.DataFrame(del_df.mean())
del_df_avg
# Out:
#                                      0
# population_sum            15025.803922
# population_male            7327.098039
# population_female          7698.705882
# population_18over_sum     13141.700980
# population_18over_male     6359.401961
# population_18over_female   6782.299020
# population_65over_sum      3414.627451
# population_65over_male     1478.460784
# population_65over_female   1936.166667

# %%
df_1dong = pd.DataFrame(df_copy[df_copy.region.str.contains('대연1동')]['population_sum'])
df_1dong
# Out:
#      population_sum
# 0             15787
# 17            15873
# 34            15905
# 51            15834
# 68            15819
# 85            15709
# 102           15677
# 119           15652
# 136           15598
# 153           15466
# 170           15384
# 187           15323

# %%
df_copy[df_copy.region.str.contains('대연1동')]['population_sum'].mean().round(2)
# Out:
# 15668.92
